# %% [markdown]
# # Experiment No. 1

# %% [markdown]
# ### Name: Vivek Vitthal Avhad (4031)

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /home/bablu/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
text = "Natural Language Processing is a subfield of Artificial Intelligence. It deals with textdata."

# %%
# Sentence Tokenization
sentences = sent_tokenize(text)
print("Sentences:", sentences)
# Out:
# Sentences: ['Natural Language Processing is a subfield of Artificial Intelligence.', 'It deals with textdata.']

# %%
# Word Tokenization
words = word_tokenize(text)
print("Words:", words)
# Out:
# Words: ['Natural', 'Language', 'Processing', 'is', 'a', 'subfield', 'of', 'Artificial', 'Intelligence', '.', 'It', 'deals', 'with', 'textdata', '.']

# %% [markdown]
# ## Student Activity:
# 1. Prepare a tokenization program using a different paragraph related to your subject.

# %%
newText = (
    "In Natural Language Processing (NLP), tokenization is the process "
    "of splitting text into smaller units called tokens. "
    "These tokens can be words, subwords, characters, or even sentences, "
    "depending on how fine-grained the analysis needs to be."
)

# %%
sentences = sent_tokenize(newText)
print("Sentences:", sentences)
# Out:
# Sentences: ['In Natural Language Processing (NLP), tokenization is the process of splitting text into smaller units called tokens These tokens can be words, subwords, characters, or even sentences, depending on how fine-grained the analysis needs to be.']

# %%
words = word_tokenize(newText)
print("Words:", words)
# Out:
# Words: ['In', 'Natural', 'Language', 'Processing', '(', 'NLP', ')', ',', 'tokenization', 'is', 'the', 'process', 'of', 'splitting', 'text', 'into', 'smaller', 'units', 'called', 'tokens', '.', 'These', 'tokens', 'can', 'be', 'words', ',', 'subwords', ',', 'characters', ',', 'or', 'even', 'sentences', ',', 'depending', 'on', 'how', 'fine-grained', 'the', 'analysis', 'needs', 'to', 'be', '.']

# %% [markdown]
# 2. Identify and count the number of words and sentences.

# %%
print("Number of sentences:", len(sentences))
print("Number of words:", len(words))
# Out:
# Number of sentences: 1
# Number of words: 45
